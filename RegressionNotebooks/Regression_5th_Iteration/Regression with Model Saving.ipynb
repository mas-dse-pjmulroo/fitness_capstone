# %%
import pandas as pd
import numpy as np
import sys
#import sources.endomondolib as endo
#import sources.pysparkconvenience as ps
from numpy import array
from math import sqrt
from pyspark.sql.functions import *
from pyspark.mllib.clustering import KMeans, KMeansModel
from pyspark.sql import DataFrameReader
from pyspark.sql import SQLContext
from IPython.display import display, HTML
from pyspark.sql.functions import col, mean, min, max
from pyspark.ml.linalg import Vectors
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression, DecisionTreeRegressor, GBTRegressor, RandomForestRegressor
from pyspark.ml.feature import StringIndexer, VectorIndexer
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, RegressionEvaluator

from pyspark.ml.feature import VectorAssembler

# Disable warnings, set Matplotlib inline plotting and load Pandas package
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
pd.options.display.mpl_style = 'default'

# %load_ext autotime

# %%
# !pwd
# Out:
# /home/ubuntu/Regression_5th_Iteration
# time: 111 ms

# %%
#sc = SQLContext()
#create pyspark dataframe from csv
def df_from_csv(csv_file):
    text = sc.textFile(csv_file)\
       .map(lambda line: line.split(','))
   #didn’t work with take(1). believe returns
   #different object then first()
    schema = text.first()
    data = text.filter(lambda x: x != schema)
    df = sqlContext.createDataFrame(data, schema)
    return df

#here’s the new vectorizer function:

def vectorizeData(data):
        return data.rdd.map(lambda r: [r[0], r[1], r[2], r[3], Vectors.dense(r[4:-1]),float(r[-1])])\
            .toDF(['route cluster', 'performance cluster', 'userid', 'workoutid', 'features', 'label'])

#load cluster csv
pandas_df = pd.read_csv('/home/ubuntu/endo_sample_6_2_1.csv')
df = sqlContext.createDataFrame(pandas_df)
# Out:
# time: 30.1 s

# %%
pandas_df.columns
# Out:
# Index([u'Unnamed: 0', u'workoutid', u'route_prediction', u'perf_prediction',
#        u'userid', u'diff_altitude', u'geo_distance', u'heart_rate_avg',
#        u'speed_avg', u'elapsed_time', u'user_avg_speed', u'user_avg_dist'],
#       dtype='object')
# time: 4.09 ms

# %%
df.show(5)
# Out:
# +----------+---------+----------------+---------------+--------+------------------+--------------+--------------+-------------+------------+-----------------+--------------+
# |Unnamed: 0|workoutid|route_prediction|perf_prediction|  userid|     diff_altitude|  geo_distance|heart_rate_avg|    speed_avg|elapsed_time|   user_avg_speed| user_avg_dist|
# +----------+---------+----------------+---------------+--------+------------------+--------------+--------------+-------------+------------+-----------------+--------------+
# |         0|327494888|               3|              2|12406103|29.205192565900003|0.296969622374| 157.123153687|9.66162204742|      9439.0|7.462391590249999|0.209828388074|
# |         1|174621145|               3|              1|  866771|  4.77955552469E-7|0.214295297861|           0.0|10.3593454361|      7998.0|    3.05411797065|0.218213216825|
# |         2| 11867693|               3|              0|  866771|  4.77955552469E-7|0.193027198315|           0.0|          0.0|      5610.0|    3.05411797065|0.218213216825|
# |         3|268802906|               3|              0|  866771|  4.77955552469E-7|0.186620146036|           0.0|          0.0|      5302.0|    3.05411797065|0.218213216825|
# |         4|285918512|               3|              0|  866771|  4.77955552469E-7|0.223394304514|           0.0|          0.0|      5733.0|    3.05411797065|0.218213216825|
# +----------+---------+----------------+---------------+--------+------------------+--------------+--------------+-------------+------------+-----------------+--------------+
# only showing top 5 rows
#
# time: 1.36 s

# %%
df.schema
# Out:
# StructType(List(StructField(Unnamed: 0,LongType,true),StructField(workoutid,LongType,true),StructField(route_prediction,LongType,true),StructField(perf_prediction,LongType,true),StructField(userid,LongType,true),StructField(diff_altitude,DoubleType,true),StructField(geo_distance,DoubleType,true),StructField(heart_rate_avg,DoubleType,true),StructField(speed_avg,DoubleType,true),StructField(elapsed_time,DoubleType,true),StructField(user_avg_speed,DoubleType,true),StructField(user_avg_dist,DoubleType,true)))
# time: 2.23 ms

# %%
select_columns = ['route_prediction', 'perf_prediction','userid', 'workoutid', 'geo_distance', 'diff_altitude', \
                'user_avg_dist', 'user_avg_speed', 'elapsed_time']

reg_df = vectorizeData(df.select(select_columns))
# Out:
# time: 395 ms

# %%
route_clusters = reg_df.select('route cluster').distinct().collect()
perf_clusters = reg_df.select('performance cluster').distinct().collect()
route_cluster_numbers = [int(route_clusters[i][0]) for i in range(len(route_clusters))]
perf_cluster_numbers = [int(perf_clusters[i][0]) for i in range(len(perf_clusters))]
# Out:
# time: 4.69 s

# %%
print "Cluster Summaries"
for n in perf_cluster_numbers:
    for i in route_cluster_numbers:
        temp_df = reg_df[(reg_df['route cluster'] == i) & (reg_df['performance cluster'] == n)]
        print 'Route%d_Perf%d:' % (i, n)
        temp_df.describe('label').show()
# Out:
# Cluster Summaries
# Route0_Perf0:
# +-------+-----------------+
# |summary|            label|
# +-------+-----------------+
# |  count|            37716|
# |   mean|3555.609900307562|
# | stddev|888.5164729306092|
# |    min|            553.0|
# |    max|           7149.0|
# +-------+-----------------+
#
# Route1_Perf0:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             45877|
# |   mean|1738.0090895219828|
# | stddev| 804.1243151589644|
# |    min|             500.0|
# |    max|            5105.0|
# +-------+------------------+
#
# Route3_Perf0:
# +-------+-----------------+
# |summary|            label|
# +-------+-----------------+
# |  count|             4901|
# |   mean|6402.024892879004|
# | stddev|1726.207035668799|
# |    min|           1014.0|
# |    max|          12174.0|
# +-------+-----------------+
#
# Route2_Perf0:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|              5985|
# |   mean|3763.0765246449455|
# | stddev| 1186.662242974958|
# |    min|             508.0|
# |    max|            7340.0|
# +-------+------------------+
#
# Route4_Perf0:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             25493|
# |   mean|2610.5288902836073|
# | stddev| 945.0472737790651|
# |    min|             501.0|
# |    max|            6207.0|
# +-------+------------------+
#
# Route0_Perf1:
# +-------+-----------------+
# |summary|            label|
# +-------+-----------------+
# |  count|            39056|
# |   mean|3675.835313396149|
# | stddev|934.3741796164328|
# |    min|            877.0|
# |    max|           7148.0|
# +-------+-----------------+
#
# Route1_Perf1:
# +-------+-----------------+
# |summary|            label|
# +-------+-----------------+
# |  count|            45208|
# |   mean|1636.209365599009|
# | stddev|709.3302795382627|
# |    min|            500.0|
# |    max|           5098.0|
# +-------+-----------------+
#
# Route3_Perf1:
# +-------+-----------------+
# |summary|            label|
# +-------+-----------------+
# |  count|            12645|
# |   mean|6044.311822854884|
# | stddev|1541.849446308188|
# |    min|           1123.0|
# |    max|          12162.0|
# +-------+-----------------+
#
# Route2_Perf1:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|              1878|
# |   mean| 7098.525026624068|
# | stddev|1406.7776318405322|
# |    min|            4089.0|
# |    max|           10273.0|
# +-------+------------------+
#
# Route4_Perf1:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             14365|
# |   mean|2607.2706578489383|
# | stddev| 938.9674380622463|
# |    min|             502.0|
# |    max|            6189.0|
# +-------+------------------+
#
# Route0_Perf2:
# +-------+-----------------+
# |summary|            label|
# +-------+-----------------+
# |  count|            15167|
# |   mean|3760.843541900178|
# | stddev|991.6933158557495|
# |    min|           1093.0|
# |    max|           7149.0|
# +-------+-----------------+
#
# Route1_Perf2:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             18901|
# |   mean|2019.5293370721126|
# | stddev| 957.8637936272237|
# |    min|             500.0|
# |    max|            5107.0|
# +-------+------------------+
#
# Route3_Perf2:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             14276|
# |   mean| 6221.450966657327|
# | stddev|1674.9348414579335|
# |    min|            1592.0|
# |    max|           12186.0|
# +-------+------------------+
#
# Route2_Perf2:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|              5656|
# |   mean| 3844.370226308345|
# | stddev|1199.6317509494895|
# |    min|             506.0|
# |    max|            7114.0|
# +-------+------------------+
#
# Route4_Perf2:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|              3851|
# |   mean|2445.9233965203844|
# | stddev| 840.3032894653136|
# |    min|             500.0|
# |    max|            5778.0|
# +-------+------------------+
#
# time: 17 s

# %%
#model_dictionary
model_dict = {}
model_dict['lr'] = {'model': LinearRegression(featuresCol="features", labelCol="label"),\
                    'param': "ParamGridBuilder() \
                    .addGrid(temp_lr.maxIter, [5, 10]) \
                    .addGrid(temp_lr.regParam, [0, 0.1, 1,10]) \
                    .addGrid(temp_lr.elasticNetParam, [0,0.5,1]) \
                    .build()"}

model_dict['dt'] = {'model': DecisionTreeRegressor(featuresCol="features", labelCol="label",maxMemoryInMB=1028),\
                    'param': "ParamGridBuilder() \
                    .addGrid(temp_lr.maxDepth, [3, 5]) \
                    .addGrid(temp_lr.minInfoGain, [0, 0.1, 1]) \
                    .build()"}

model_dict['gbt'] = {'model': GBTRegressor(featuresCol="features", labelCol="label", maxMemoryInMB=2056),\
                    'param': "ParamGridBuilder() \
                    .addGrid(temp_lr.maxDepth, [3, 5]) \
                    .addGrid(temp_lr.maxIter, [10,20,40]) \
                    .build()"}

model_dict['rfr'] = {'model': RandomForestRegressor(featuresCol="features", labelCol="label", maxMemoryInMB = 2056),\
                    'param': "ParamGridBuilder() \
                    .addGrid(temp_lr.maxDepth, [3, 5]) \
                    .addGrid(temp_lr.numTrees, [10,20,40]) \
                    .build()"}
# Out:
# time: 171 ms

# %% [markdown]
# #Truncated param maps for speed in model_dictionary
# model_dict = {}
# model_dict['lr'] = {'model': LinearRegression(featuresCol="features", labelCol="label"),\
#                     'param': "ParamGridBuilder() \
#                     .addGrid(temp_lr.regParam, [0, 0.1, 0.01]) \
#                     .build()"}
#
# model_dict['dt'] = {'model': DecisionTreeRegressor(featuresCol="features", labelCol="label",maxMemoryInMB=1028),\
#                     'param': "ParamGridBuilder() \
#                     .addGrid(temp_lr.maxDepth, [3, 5]) \
#                     .build()"}
#
# #model_dict['gbt'] = {'model': GBTRegressor(featuresCol="features", labelCol="label", maxMemoryInMB=2056),\
# #                    'param': "ParamGridBuilder() \
# #                    .addGrid(temp_lr.maxDepth, [3, 5]) \
# #                    .build()"}
#
# model_dict['rfr'] = {'model': RandomForestRegressor(featuresCol="features", labelCol="label", maxMemoryInMB = 2056),\
#                     'param': "ParamGridBuilder() \
#                     .addGrid(temp_lr.maxDepth, [3, 5]) \
#                     .build()"}

# %%
fit_model_dict = {}
# Out:
# time: 950 µs

# %%
reg_df.show(5)
# Out:
# +-------------+-------------------+--------+---------+--------------------+------+
# |route cluster|performance cluster|  userid|workoutid|            features| label|
# +-------------+-------------------+--------+---------+--------------------+------+
# |            3|                  2|12406103|327494888|[0.296969622374,2...|9439.0|
# |            3|                  1|  866771|174621145|[0.214295297861,4...|7998.0|
# |            3|                  0|  866771| 11867693|[0.193027198315,4...|5610.0|
# |            3|                  0|  866771|268802906|[0.186620146036,4...|5302.0|
# |            3|                  0|  866771|285918512|[0.223394304514,4...|5733.0|
# +-------------+-------------------+--------+---------+--------------------+------+
# only showing top 5 rows
#
# time: 120 ms

# %%
reg_df.schema
# Out:
# StructType(List(StructField(route cluster,LongType,true),StructField(performance cluster,LongType,true),StructField(userid,LongType,true),StructField(workoutid,LongType,true),StructField(features,VectorUDT,true),StructField(label,DoubleType,true)))
# time: 2.3 ms

# %%
results_df = reg_df.toPandas().set_index(['workoutid'])
# Out:
# time: 36.9 s

# %%
results_df['lr'] = None
results_df['rfr'] = None
results_df['dt'] = None
results_df['gbt'] = None
# Out:
# time: 16.5 ms

# %%
results_df.head()
# Out:
#            route cluster  performance cluster    userid  \
# workoutid
# 327494888              3                    2  12406103
# 174621145              3                    1    866771
# 11867693               3                    0    866771
# 268802906              3                    0    866771
# 285918512              3                    0    866771
#
#                                                     features   label    lr  \
# workoutid
# 327494888  [0.296969622374, 29.2051925659, 0.209828388074...  9439.0  None
# 174621145  [0.214295297861, 4.77955552469e-07, 0.21821321...  7998.0  None
# 11867693   [0.193027198315, 4.77955552469e-07, 0.21821321...  5610.0  None
# 268802906  [0.186620146036, 4.77955552469e-07, 0.21821321...  5302.0  None
# 285918512  [0.223394304514, 4.77955552469e-07, 0.21821321...  5733.0  None
#
#             rfr   dtr   gbt
# workoutid
# 327494888  None  None  None
# 174621145  None  None  None
# 11867693   None  None  None
# 268802906  None  None  None
# 285918512  None  None  None
# time: 17.8 ms

# %%
for m in model_dict.keys():
    for n in perf_cluster_numbers:
        for i in route_cluster_numbers:
            temp_df = reg_df[(reg_df['route cluster'] == i) & (reg_df['performance cluster'] == n)]
            #temp_df1 = reg_df[reg_df['route cluster']==i]
            #temp_df = temp_df1[reg_df['performance cluster']==n]
            temp_df_cv = temp_df

            if temp_df.count() < 5:
                print "Cluster pair dropped: Route%d_Perf%d_%s" % (i,n,m)
                pass

            else:
                temp_lr = model_dict[m]['model']
                temp_lrModel = temp_lr.fit(temp_df['label','features'])
                temp_df = temp_lrModel.transform(temp_df)

                paramGrid = eval(model_dict[m]['param'])
                #paramGrid = ParamGridBuilder() \
                #.addGrid(temp_lr.maxDepth, [3, 5]) \
                #.addGrid(temp_lr.numTrees, [10,20,40]) \
                #.build()


                evaluator = RegressionEvaluator(
                    labelCol="label", predictionCol="prediction", metricName="mae")

                crossval = CrossValidator(estimator=temp_lr,
                                          estimatorParamMaps=paramGrid,
                                          evaluator=evaluator,
                                          numFolds=10)  

                # Run cross-validation, and choose the best set of parameters.
                cvModel = crossval.fit(temp_df_cv)

                pred = cvModel.transform(temp_df_cv)

                pd_pred = pred.toPandas().set_index(['workoutid'])
                results_df.ix[pd_pred.index, m] = pd_pred.prediction

                
                #print("For " + str(type(temp_lr)) + " and cluster " + str(i))
                #print(cvModel.explainParams())

                #Print the coefficients and intercept for linear regression
                #print("Coefficients: " + str(temp_lrModel.coefficients))
                #print("Intercept: " + str(temp_lrModel.intercept))


                
                mae = evaluator.evaluate(pred)
                rmse = evaluator.evaluate(pred,{evaluator.metricName: "rmse"})
                r2 = evaluator.evaluate(pred, {evaluator.metricName: "r2"})

                fit_model_dict['Route%d_Perf%d_%s' % (i,n,m)]={}
                fit_model_dict['Route%d_Perf%d_%s' % (i,n,m)]['mae'] = mae
                fit_model_dict['Route%d_Perf%d_%s' % (i,n,m)]['rmse'] = rmse
                fit_model_dict['Route%d_Perf%d_%s' % (i,n,m)]['r2'] = r2
                #fit_model_dict['Route%d_Perf%d_%s' % (i,n,m)]['model'] = cvModel.bestModel
                

                
                print("(Route, Perf, Model): " + str((i,n,m)) +": " + str(rmse))
                print(cvModel.bestModel)
                #print(cvModel.bestModel.weights)
                #print(cvModel.bestModel.coefficients)
                basePath = "/home/ubuntu/Regression_5th_Iteration/Models/"
                cvModel.bestModel.save(basePath +"Route%d_Perf%d_%s" % (i,n,m))
                
                fit_model_dict['Route%d_Perf%d_%s' % (i,n,m)]["path"] = basePath +"Route%d_Perf%d_%s" % (i,n,m)
# Out:
# (Route, Perf, Model): (0, 0, 'rfr'): 692.503825975
# RandomForestRegressionModel (uid=rfr_40a3f763d0bb) with 10 trees
# (Route, Perf, Model): (1, 0, 'rfr'): 553.446929595
# RandomForestRegressionModel (uid=rfr_f64a634c26aa) with 20 trees
# (Route, Perf, Model): (3, 0, 'rfr'): 1386.04953647
# RandomForestRegressionModel (uid=rfr_00c91f61b84f) with 40 trees
# (Route, Perf, Model): (2, 0, 'rfr'): 688.865936667
# RandomForestRegressionModel (uid=rfr_5aeef92c9195) with 20 trees
# (Route, Perf, Model): (4, 0, 'rfr'): 681.062080983
# RandomForestRegressionModel (uid=rfr_49302d02e358) with 40 trees
# (Route, Perf, Model): (0, 1, 'rfr'): 717.100507449
# RandomForestRegressionModel (uid=rfr_2287752284e4) with 20 trees
# (Route, Perf, Model): (1, 1, 'rfr'): 462.123878538
# RandomForestRegressionModel (uid=rfr_6b1422382d6f) with 20 trees
# (Route, Perf, Model): (3, 1, 'rfr'): 1197.63947839
# RandomForestRegressionModel (uid=rfr_e38df1fa7cb2) with 40 trees
# (Route, Perf, Model): (2, 1, 'rfr'): 1121.37401119
# RandomForestRegressionModel (uid=rfr_5fd3f803c30b) with 40 trees
# (Route, Perf, Model): (4, 1, 'rfr'): 634.275725273
# RandomForestRegressionModel (uid=rfr_35c591e1f263) with 10 trees
# (Route, Perf, Model): (0, 2, 'rfr'): 765.707937686
# RandomForestRegressionModel (uid=rfr_55ec0345b21c) with 20 trees
# (Route, Perf, Model): (1, 2, 'rfr'): 776.304687455
# RandomForestRegressionModel (uid=rfr_1fe46b253033) with 20 trees
# (Route, Perf, Model): (3, 2, 'rfr'): 1340.02539145
# RandomForestRegressionModel (uid=rfr_5a3b3fd37195) with 20 trees
# (Route, Perf, Model): (2, 2, 'rfr'): 749.6369378
# RandomForestRegressionModel (uid=rfr_4091119aa153) with 10 trees
# (Route, Perf, Model): (4, 2, 'rfr'): 477.390814538
# RandomForestRegressionModel (uid=rfr_d4b94da6b281) with 20 trees
# (Route, Perf, Model): (0, 0, 'dt'): 697.277769894
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (1, 0, 'dt'): 557.320718763
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (3, 0, 'dt'): 1420.60108099
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (2, 0, 'dt'): 698.361871622
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 61 nodes
# (Route, Perf, Model): (4, 0, 'dt'): 683.540045479
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (0, 1, 'dt'): 719.008216822
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (1, 1, 'dt'): 462.097242258
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (3, 1, 'dt'): 1218.88290881
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (2, 1, 'dt'): 1153.74765411
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (4, 1, 'dt'): 637.619521438
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (0, 2, 'dt'): 775.848933569
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (1, 2, 'dt'): 787.307369206
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (3, 2, 'dt'): 1364.8842031
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (2, 2, 'dt'): 761.037796811
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (4, 2, 'dt'): 490.756506778
# DecisionTreeRegressionModel (uid=DecisionTreeRegressor_4773b315f1facadaae72) of depth 5 with 63 nodes
# (Route, Perf, Model): (0, 0, 'lr'): 713.642487846
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (1, 0, 'lr'): 588.367672883
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (3, 0, 'lr'): 1497.95545369
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (2, 0, 'lr'): 728.591054931
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (4, 0, 'lr'): 697.487936065
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (0, 1, 'lr'): 740.144526265
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (1, 1, 'lr'): 468.840207732
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (3, 1, 'lr'): 1246.84144646
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (2, 1, 'lr'): 1265.36256155
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (4, 1, 'lr'): 652.728175474
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (0, 2, 'lr'): 803.778045899
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (1, 2, 'lr'): 816.743422956
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (3, 2, 'lr'): 1404.5504224
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (2, 2, 'lr'): 792.660743284
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (4, 2, 'lr'): 512.496586692
# LinearRegression_4b79a649a9f1d5d5db2c
# (Route, Perf, Model): (0, 0, 'gbt'): 591.385644409
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (1, 0, 'gbt'): 470.748454137
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (3, 0, 'gbt'): 1077.03164158
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (2, 0, 'gbt'): 538.818789218
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (4, 0, 'gbt'): 577.409825826
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (0, 1, 'gbt'): 592.279256881
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (1, 1, 'gbt'): 406.469258787
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (3, 1, 'gbt'): 951.097485026
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (2, 1, 'gbt'): 778.369729612
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (4, 1, 'gbt'): 508.611799862
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (0, 2, 'gbt'): 630.684104481
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (1, 2, 'gbt'): 662.694806173
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (3, 2, 'gbt'): 1043.83656943
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (2, 2, 'gbt'): 583.643616743
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# (Route, Perf, Model): (4, 2, 'gbt'): 340.550291971
# GBTRegressionModel (uid=GBTRegressor_44a49dbbc66e7568cb64) with 40 trees
# time: 19h 1min 23s

# %%
fit_model_df = pd.DataFrame.from_dict(fit_model_dict, orient = 'index')
# Out:
# time: 5.04 ms

# %%
fit_model_df
# Out:
#                                                                path  \
# Route0_Perf0_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf0_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf0_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf0_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf1_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf1_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf1_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf1_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf2_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf2_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf2_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route0_Perf2_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf0_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf0_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf0_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf0_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf1_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf1_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf1_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf1_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf2_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf2_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf2_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route1_Perf2_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf0_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf0_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf0_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf0_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf1_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf1_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf1_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf1_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf2_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf2_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf2_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route2_Perf2_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf0_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf0_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf0_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf0_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf1_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf1_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf1_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf1_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf2_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf2_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf2_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route3_Perf2_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf0_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf0_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf0_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf0_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf1_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf1_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf1_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf1_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf2_dt   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf2_gbt  /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf2_lr   /home/ubuntu/Regression_5th_Iteration/Models/R...
# Route4_Perf2_rfr  /home/ubuntu/Regression_5th_Iteration/Models/R...
#
#                           mae        r2         rmse
# Route0_Perf0_dt    529.494504  0.384126   697.277770
# Route0_Perf0_gbt   431.621336  0.556981   591.385644
# Route0_Perf0_lr    544.488171  0.354878   713.642488
# Route0_Perf0_rfr   526.111130  0.392530   692.503826
# Route0_Perf1_dt    545.740507  0.407843   719.008217
# Route0_Perf1_gbt   432.063304  0.598188   592.279257
# Route0_Perf1_lr    566.879338  0.372516   740.144526
# Route0_Perf1_rfr   546.291741  0.410981   717.100507
# Route0_Perf2_dt    580.078532  0.387892   775.848934
# Route0_Perf2_gbt   453.266263  0.595519   630.684104
# Route0_Perf2_lr    611.246608  0.343029   803.778046
# Route0_Perf2_rfr   576.398601  0.403789   765.707938
# Route1_Perf0_dt    396.459592  0.519633   557.320719
# Route1_Perf0_gbt   319.165550  0.657279   470.748454
# Route1_Perf0_lr    414.622257  0.464622   588.367673
# Route1_Perf0_rfr   394.385624  0.526287   553.446930
# Route1_Perf1_dt    333.554572  0.575596   462.097242
# Route1_Perf1_gbt   284.090006  0.671627   406.469259
# Route1_Perf1_lr    340.716422  0.563120   468.840208
# Route1_Perf1_rfr   334.567341  0.575547   462.123879
# Route1_Perf2_dt    589.025198  0.324378   787.307369
# Route1_Perf2_gbt   472.959142  0.521323   662.694806
# Route1_Perf2_lr    614.828961  0.272912   816.743423
# Route1_Perf2_rfr   584.966198  0.343129   776.304687
# Route2_Perf0_dt    548.344147  0.653599   698.361872
# Route2_Perf0_gbt   411.278014  0.793793   538.818789
# Route2_Perf0_lr    569.900507  0.622961   728.591055
# Route2_Perf0_rfr   542.481221  0.662955   688.865937
# Route2_Perf1_dt    900.614851  0.327020  1153.747654
# Route2_Perf1_gbt   600.613998  0.693696   778.369730
# Route2_Perf1_lr   1010.708064  0.190512  1265.362562
# Route2_Perf1_rfr   882.738726  0.364257  1121.374011
# Route2_Perf2_dt    569.877280  0.597475   761.037797
# Route2_Perf2_gbt   427.809315  0.763257   583.643617
# Route2_Perf2_lr    605.468103  0.563328   792.660743
# Route2_Perf2_rfr   566.703289  0.609444   749.636938
# Route3_Perf0_dt   1056.334112  0.322597  1420.601081
# Route3_Perf0_gbt   775.741210  0.610632  1077.031642
# Route3_Perf0_lr   1120.795754  0.246817  1497.955454
# Route3_Perf0_rfr  1037.981834  0.355148  1386.049536
# Route3_Perf1_dt    913.305332  0.375008  1218.882909
# Route3_Perf1_gbt   689.221090  0.619460   951.097485
# Route3_Perf1_lr    945.384043  0.346007  1246.841446
# Route3_Perf1_rfr   900.366506  0.396604  1197.639478
# Route3_Perf2_dt   1035.183724  0.335911  1364.884203
# Route3_Perf2_gbt   766.854792  0.611582  1043.836569
# Route3_Perf2_lr   1067.829970  0.296751  1404.550422
# Route3_Perf2_rfr  1014.285406  0.359881  1340.025391
# Route4_Perf0_dt    495.914564  0.476836   683.540045
# Route4_Perf0_gbt   400.129209  0.626683   577.409826
# Route4_Perf0_lr    507.793108  0.455267   697.487936
# Route4_Perf0_rfr   494.134980  0.480622   681.062081
# Route4_Perf1_dt    479.574946  0.538839   637.619521
# Route4_Perf1_gbt   363.127018  0.706572   508.611800
# Route4_Perf1_lr    492.244329  0.516725   652.728175
# Route4_Perf1_rfr   478.462967  0.543663   634.275725
# Route4_Perf2_dt    366.640769  0.658828   490.756507
# Route4_Perf2_gbt   248.002719  0.835713   340.550292
# Route4_Perf2_lr    381.502855  0.627932   512.496587
# Route4_Perf2_rfr   355.862395  0.677159   477.390815
# time: 33.2 ms

# %%
results_df
# Out:
#            route cluster  performance cluster    userid  \
# workoutid
# 327494888              3                    2  12406103
# 174621145              3                    1    866771
# 11867693               3                    0    866771
# 268802906              3                    0    866771
# 285918512              3                    0    866771
# 454249158              3                    0   7710890
# 674628540              3                    1   1058434
# 524268591              3                    2   1058434
# 458967418              3                    1   2226932
# 255209949              3                    1   2675116
# 329073982              3                    0   7580364
# 308734030              3                    2   3417701
# 380194852              3                    2   4124709
# 300200351              3                    2   4124709
# 399316838              3                    1   9889560
# 419050891              3                    0   9889560
# 493498813              3                    1   2844791
# 328365115              3                    1   2844791
# 285096943              3                    1   2844791
# 614702117              3                    2   9221677
# 614715116              3                    2   9221677
# 608974115              3                    0   3455568
# 603290131              3                    0   3455568
# 323717050              3                    2   7996903
# 524105996              3                    2   9345869
# 449255978              3                    2   9655659
# 323105090              3                    1    875281
# 323105213              3                    1    875281
# 323105166              3                    1    875281
# 167478855              3                    2   1812737
# ...                  ...                  ...       ...
# 266001324              2                    0   4198916
# 294587807              2                    1   4198916
# 266000632              2                    2   4198916
# 485565823              2                    1   1023513
# 472766538              2                    0   4146688
# 167413722              2                    2   4146688
# 295104861              2                    0   4146688
