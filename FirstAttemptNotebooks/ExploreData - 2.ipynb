# %%
import sys
import ujson
import pprint
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from operator import itemgetter
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# For displaying google maps
import gmplot
from IPython.display import IFrame

# Second (better?) google map, only inline so far
import gmaps

# For summary stats
import scipy
from scipy import stats

# For testing a subset of the data
from copy import deepcopy

pp = pprint.PrettyPrinter(indent=4)
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Read config from local file
GMAP_API_KEY = None

sys.path.append('/Users/patrickmulrooney/Desktop/')
import capstone_config

_file = capstone_config._INPUT_FILE_2
GMAP_API_KEY = capstone_config._GMAP_API_KEY

gmaps.configure(api_key=GMAP_API_KEY)

print _file
# Out:
# /Users/patrickmulrooney/Downloads/endomondoHR/endoHRParsed.json

# %%
# Testing auto adding time output to all cells
'''
#To install...
wget https://raw.githubusercontent.com/cpcloud/ipython-autotime/master/autotime.py
#Make available via
jupyter nbextension install /Users/patrickmulrooney/class/notebooks/pjmulroo/DSECapstone/autotime.py
'''
 
# %load_ext autotime

# %%
def log_progress(sequence, every=None, size=None):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{index} / ?'.format(index=index)
                else:
                    progress.value = index
                    label.value = u'{index} / {size}'.format(
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = str(index or '?')
# Out:
# time: 122 ms

# %% [markdown]
# # Working with data already parsed from LoadData - 1 notebook
# ## Load parsed data

# %%
#time: 12min 44s
# Set via config file
# Full dataset
#_file = "/Users/patrickmulrooney/Downloads/endomondoHR/endoHRParsed.json"
# Full dataset, outliers removed
#_file = "/Users/patrickmulrooney/Downloads/endomondoHR/endoHRParsed_no_outliers.json"
# Partial dataset
#_file = "/Users/patrickmulrooney/Downloads/endomondoHR/endoHRParsed_10k.json"
# Partial dataset, outliers removed
#_file = "/Users/patrickmulrooney/Downloads/endomondoHR/endoHRParsed_no_outliers_10k.json"

endoHR = []

with open(_file, 'r') as f:
    endoHR += ujson.load(f)
# Out:
# time: 14min 27s

# %%
print "Length of import: %s"%(len(endoHR))
# Out:
# Length of import: 253020
# time: 17.7 ms

# %%
## Used between cells

# List of all the exercise types in the dataset
exercise_types = {}

# Keys in each record
all_keys = []


series_keys = { True: ['timestamp', 'heart_rate', 'altitude', 'latitude', 'longitude', 'speed' ], \
               False: ['timestamp', 'heart_rate', 'altitude', 'latitude', 'longitude'] }
# Out:
# time: 7.82 ms

# %%
# See what keys still remain.
sports = {}
count = 0
for _endoHR in log_progress(endoHR, every=1):
    all_keys += _endoHR.keys()
    _sport = _endoHR[ 'sport' ]
    try:
        sports[_sport] += 1
    except:
        sports[_sport] = 1
        
    if _sport not in exercise_types.keys():
        exercise_types[_sport] = count
        count += 1

# Drop dupes
all_keys = set( all_keys )

sports2 = []

for k,v in sports.iteritems():
    sports2.append((k,v))

print "What keys remain?"
pp.pprint( all_keys )

print ""
print ""

print "What sports?"
pp.pprint( sorted(sports2, key=itemgetter(1), reverse=True) )
# Out:
# What keys remain?
# set([   u'gender',
#         u'id',
#         u'series',
#         u'speed_included',
#         u'sport',
#         u'url',
#         u'userId'])
#
#
# What sports?
# [   (u'run', 117902),
#     (u'bike', 98001),
#     (u'mountain bike', 13510),
#     (u'bike (transport)', 10445),
#     (u'walk', 3831),
#     (u'indoor cycling', 2606),
#     (u'core stability training', 1262),
#     (u'orienteering', 1197),
#     (u'cross-country skiing', 949),
#     (u'skate', 512),
#     (u'roller skiing', 408),
#     (u'fitness walking', 402),
#     (u'hiking', 357),
#     (u'kayaking', 255),
#     (u'weight training', 237),
#     (u'circuit training', 218),
#     (u'gymnastics', 162),
#     (u'downhill skiing', 144),
#     (u'rowing', 127),
#     (u'elliptical', 83),
#     (u'soccer', 71),
#     (u'treadmill running', 70),
#     (u'aerobics', 46),
#     (u'swimming', 41),
#     (u'snowshoeing', 32),
#     (u'yoga', 22),
#     (u'badminton', 17),
#     (u'horseback riding', 16),
#     (u'basketball', 14),
#     (u'stair climing', 13),
#     (u'golf', 12),
#     (u'tennis', 8),
#     (u'pilates', 7),
#     (u'rugby', 7),
#     (u'climbing', 6),
#     (u'martial arts', 5),
#     (u'table tennis', 5),
#     (u'snowboarding', 5),
#     (u'beach volleyball', 2),
#     (u'sailing', 2),
#     (u'step counter', 2),
#     (u'treadmill walking', 2),
#     (u'skateboarding', 1),
#     (u'dancing', 1),
#     (u'windsurfing', 1),
#     (u'wheelchair', 1),
#     (u'squash', 1),
#     (u'kite surfing', 1),
#     (u'scuba diving', 1)]
# time: 7min 35s

# %%
seriesLength = []

for _endoHR in log_progress(endoHR, every=5):

    # For debugging purposes, get a record of length of series for histogram
    _seriesLen = len(_endoHR['series'])
    seriesLength.append(_seriesLen)
    
plt.hist(seriesLength, bins=50, log=True)
plt.show()
# Out:
# time: 1min 34s

# %% [markdown]
# ### Notes
# Looks like there must be some sort of limit with the HR stuff of 500 records per exercise, or the api not returning more than that. Need to look at this further.
#
# ### Get deltas of timestamps and speed in series.

# %%
for _endoHR in log_progress(endoHR, every=1):
    _max_time_delta = 0
    
    _timestamps = [item[0] for item in _endoHR['series']]
    _endoHR['end_start_delta'] = max(_timestamps) - min(_timestamps)

    for i,_cur in enumerate(_timestamps[:-2]):
        _next = _timestamps[i+1]
        _diff = _next - _cur
        if _diff > _max_time_delta:
            _max_time_delta = _diff
    
    _endoHR['max_time_delta'] = _max_time_delta
    
    if _endoHR['speed_included']:
        _max_speed_delta = 0
        _max_speed = 0
        
        _speeds = [item[5] for item in _endoHR['series']]

        for i,_cur in enumerate(_speeds[:-2]):
            _next = _speeds[i+1]
            _diff = _next - _cur
            
            if _diff > _max_speed_delta:
                _max_speed_delta = _diff
                
            if _cur > _max_speed:
                _max_speed = _cur
    
        _endoHR['max_speed'] = _max_speed
        _endoHR['max_speed_delta'] = _max_speed_delta
# Out:
# time: 10min 35s

# %%
# See how long 
pd.set_option('display.float_format', lambda x: '%.3f' % x)

_esd = sorted([(item['end_start_delta']/60) for item in endoHR])

print pd.Series(_esd).describe()

# Based on summary stats, lets only keep those less than 6 hours. Beyond that is crazy.
#_esd = [_i for _i in _esd if _i < 360]
_esd = [_i for _i in _esd if _i < 2880]


plt.hist(_esd,bins=200,log=True)
plt.show()
# Out:
# count    253020.000
# mean        450.713
# std       41235.656
# min           0.000
# 25%          32.000
# 50%          58.000
# 75%         102.000
# max     9908696.000
# dtype: float64
# time: 3.51 s

# %% [markdown]
# ## Figure out where these people are.

# %%
#time: 9min 12s
lat_longs = []

for _endoHR in log_progress(endoHR, every=1):
    _series = _endoHR['series'][0]
    lat_longs.append([_series[3], _series[4], _endoHR['sport']])
# Out:
# time: 8min 2s

# %%
#time: 7.94 s
# Write the lat longs to file, need to figure out how to map. Probably google maps and kml, try basemap below.

target = open("/tmp/lat_longs.txt", 'w')
for i in lat_longs:
    target.write("%s,%s\n"%(i[0],i[1]))
    
target.close()
# Out:
# time: 1.02 s

# %%
lats = [ _i[0] for _i in lat_longs ]
lons = [ _i[1] for _i in lat_longs ]
sport_type = [ exercise_types[_i[2]] for _i in lat_longs ]
# Out:
# time: 897 ms

# %%
# Americas
plt.figure(figsize=(12,12))
m = Basemap(width=15000000,height=20000000,resolution='i',projection='stere', lat_ts=0,lat_0=10,lon_0=-80.)
x, y = m(lons,lats)
m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff',zorder=0)
m.scatter(x,y,1, marker='o')
m.drawcountries()
plt.show()
# Out:
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3222: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:3231: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# time: 38.7 s

# %%
# Europe, Africa, Asia, etc
plt.figure(figsize=(12,12))
m = Basemap(width=30000000,height=20000000,resolution='i',projection='stere', lat_ts=0,lat_0=10,lon_0=80.)
x, y = m(lons,lats)
m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff',zorder=0)
m.scatter(x,y,1, marker='o')
m.drawcountries()
plt.show()
# Out:
# time: 35.3 s

# %%
#US
lat=40
lon=-100

plt.figure(figsize=(12,12))
m = Basemap(width=5000000,height=3000000,resolution='h',projection='stere', lat_ts=0,lat_0=lat,lon_0=lon)
x, y = m(lons,lats)
m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff',zorder=0)
m.scatter(x,y,1, marker='o')
m.drawcountries()
plt.show()
# Out:
# time: 48.6 s

# %%
#Europe
lat=50
lon=10

plt.figure(figsize=(12,12))
m = Basemap(width=5000000,height=3000000,resolution='h',projection='stere', lat_ts=0,lat_0=lat,lon_0=lon)
x, y = m(lons,lats)
m.drawmapboundary(fill_color='#99ffff')
m.fillcontinents(color='#cc9966',lake_color='#99ffff',zorder=0)
m.scatter(x,y,1, marker='o')
m.drawcountries()
plt.show()
# Out:
# time: 40 s

# %%
lats_rounded = [ float("{0:.4f}".format(_i)) for _i in lats ]
lons_rounded = [ float("{0:.4f}".format(_i)) for _i in lons ]
sport_type = [ exercise_types[_i[2]] for _i in lat_longs ]

# # declare the center of the map, and how much we want the map zoomed in
# gmap = gmplot.GoogleMapPlotter(0, 0, 2)
# # plot heatmap
# gmap.heatmap(lats_rounded, lons_rounded)

# gmap.draw("/tmp/workout_heatmap.html")

m = gmaps.Map()
heatmap_layer = gmaps.Heatmap(data=zip(lats_rounded, lons_rounded))
m.add_layer(heatmap_layer)

heatmap_layer.max_intensity = 90
heatmap_layer.point_radius = 3
m
# Out:
# time: 5.06 s

# %% [markdown]
# #### Notes
# * Really popular in Copenhagen. Endomundo was founded in Copenhagen.
# * Really popular in Bangkok. No idea why
#
# ## Figure out who works out the most, and how much

# %%
#time: 9min 51s
_uid_freq = {}
for _endoHR in log_progress(endoHR, every=5):
    try:
        _uid_freq[_endoHR['userId']] += 1
    except:
        _uid_freq[_endoHR['userId']] = 1
        
_uid_freq2 = []

for k,v in _uid_freq.iteritems():
    _uid_freq2.append((k,v))

print "Top 100 users"
pp.pprint( sorted(_uid_freq2, key=itemgetter(1), reverse=True)[:100] )
# Out:
# Top 100 users
# [   (3714939, 2905),
#     (1063624, 2163),
#     (1520156, 1832),
#     (10821441, 1666),
#     (2915343, 1577),
#     (2734298, 1542),
#     (65547, 1279),
#     (8276277, 1272),
#     (846598, 1250),
#     (797841, 1246),
#     (804068, 1171),
#     (2474825, 1126),
#     (3347250, 1107),
#     (9051351, 1096),
#     (4439016, 1090),
#     (983950, 1072),
#     (2461936, 1022),
#     (4997910, 1013),
#     (860533, 994),
#     (2484395, 949),
#     (538524, 938),
#     (196571, 936),
#     (4535678, 925),
#     (2894897, 923),
#     (212295, 919),
#     (508935, 918),
#     (7516129, 915),
#     (8446566, 895),
#     (14066832, 894),
#     (510054, 889),
#     (2145516, 878),
#     (2486861, 871),
#     (751448, 846),
#     (14176671, 845),
#     (764981, 834),
#     (4446822, 833),
#     (12200275, 825),
#     (4774109, 817),
#     (56291, 811),
#     (2600099, 809),
#     (3736342, 796),
#     (2333172, 794),
#     (1706844, 781),
#     (1998312, 780),
#     (4496645, 775),
#     (7996903, 771),
#     (2102320, 766),
#     (5979382, 761),
#     (791908, 747),
#     (9882712, 733),
#     (11884453, 730),
#     (68009, 715),
#     (432096, 714),
#     (13149722, 712),
#     (6692748, 703),
#     (3987593, 695),
#     (6601602, 694),
#     (9335429, 694),
#     (10719156, 687),
#     (775277, 684),
#     (2076057, 681),
#     (2849785, 681),
#     (9345869, 680),
#     (2282039, 668),
#     (14204020, 655),
#     (5727574, 650),
#     (6961546, 649),
#     (331586, 646),
#     (2909018, 643),
#     (3021311, 642),
#     (5278840, 641),
#     (890789, 640),
#     (2479025, 637),
#     (240120, 633),
#     (13303518, 633),
#     (4399772, 632),
#     (7178673, 630),
#     (171814, 624),
#     (3575734, 620),
#     (3289673, 615),
#     (8875079, 613),
#     (8799177, 609),
#     (11917849, 601),
#     (2155974, 600),
#     (818925, 599),
#     (368603, 592),
#     (7313790, 585),
#     (5641621, 585),
#     (4832531, 582),
#     (3411439, 580),
#     (139383, 577),
#     (4403506, 575),
#     (653747, 574),
#     (2974312, 573),
#     (1842744, 573),
#     (2358, 572),
#     (3089500, 572),
#     (745030, 567),
#     (3748741, 566),
#     (851531, 563)]
# time: 1min 54s

# %%
plt.hist(sorted([_i[1] for _i in _uid_freq2]),bins=100,log=True)
plt.show()
# Out:
# time: 895 ms

# %% [markdown]
# ### What sports did the top 100 most active users do?

# %%
#time: 9min 51s
_top_participants = [ _i[0] for _i in sorted(_uid_freq2, key=itemgetter(1), reverse=True)[:100]]

_uid_freq_detail = {}
for _endoHR in log_progress(endoHR, every=1):
    if not _endoHR['userId'] in _uid_freq_detail.keys():
        _uid_freq_detail[_endoHR['userId']] = {}
    if _endoHR['sport'] in _uid_freq_detail[_endoHR['userId']].keys():
        _uid_freq_detail[_endoHR['userId']][_endoHR['sport']] += 1
    else:
        _uid_freq_detail[_endoHR['userId']][_endoHR['sport']] = 1
        
_uid_freq_detail2 = []

for k,v in _uid_freq_detail.iteritems():
    _uid_freq_detail2.append((k,v))

sorted(_uid_freq_detail2, key=lambda x: sum(x[1].values()) , reverse=True)[:100]
# Out:
# [(3714939, {u'bike': 2783, u'run': 120, u'walk': 2}),
#  (1063624,
#   {u'bike': 271,
#    u'core stability training': 4,
#    u'cross-country skiing': 4,
#    u'hiking': 4,
#    u'run': 1874,
#    u'walk': 6}),
#  (1520156, {u'bike': 71, u'mountain bike': 2, u'run': 1755, u'walk': 4}),
#  (10821441, {u'bike': 1666}),
#  (2915343, {u'bike': 31, u'mountain bike': 30, u'run': 1516}),
#  (2734298,
#   {u'bike': 69,
#    u'bike (transport)': 1218,
#    u'downhill skiing': 3,
#    u'fitness walking': 13,
#    u'mountain bike': 234,
#    u'skate': 3,
#    u'walk': 2}),
#  (65547,
#   {u'bike': 1221,
#    u'indoor cycling': 26,
#    u'mountain bike': 31,
#    u'weight training': 1}),
#  (8276277,
#   {u'bike': 75,
#    u'bike (transport)': 7,
#    u'circuit training': 2,
#    u'core stability training': 54,
#    u'cross-country skiing': 34,
#    u'hiking': 4,
#    u'mountain bike': 790,
#    u'orienteering': 17,
#    u'roller skiing': 1,
#    u'run': 279,
#    u'treadmill running': 8,
#    u'walk': 1}),
#  (846598,
#   {u'bike': 991,
#    u'core stability training': 2,
#    u'hiking': 2,
#    u'indoor cycling': 1,
#    u'kayaking': 130,
#    u'rowing': 12,
#    u'run': 105,
#    u'swimming': 1,
#    u'walk': 5,
#    u'wheelchair': 1}),
#  (797841,
#   {u'bike': 879,
#    u'bike (transport)': 1,
#    u'indoor cycling': 3,
#    u'mountain bike': 363}),
#  (804068, {u'bike': 1033, u'run': 138}),
#  (2474825,
#   {u'bike': 15,
#    u'bike (transport)': 87,
#    u'mountain bike': 12,
#    u'roller skiing': 133,
#    u'run': 877,
#    u'skate': 2}),
#  (3347250, {u'bike': 1015, u'indoor cycling': 28, u'mountain bike': 64}),
#  (9051351,
#   {u'bike': 1057, u'indoor cycling': 19, u'mountain bike': 5, u'run': 15}),
#  (4439016,
#   {u'bike': 477,
#    u'bike (transport)': 1,
#    u'core stability training': 6,
#    u'mountain bike': 298,
#    u'run': 304,
#    u'swimming': 4}),
#  (983950,
#   {u'bike': 8,
#    u'circuit training': 1,
#    u'core stability training': 1,
#    u'run': 1062}),
#  (2461936, {u'bike (transport)': 15, u'elliptical': 2, u'run': 1005}),
#  (4997910, {u'bike': 2, u'bike (transport)': 856, u'mountain bike': 155}),
#  (860533, {u'bike': 4, u'run': 988, u'walk': 2}),
#  (2484395,
#   {u'bike': 221,
#    u'core stability training': 2,
#    u'indoor cycling': 3,
#    u'run': 723}),
#  (538524, {u'bike': 904, u'run': 34}),
#  (196571,
#   {u'bike': 20,
#    u'core stability training': 14,
#    u'orienteering': 148,
#    u'run': 754}),
#  (4535678, {u'bike': 923, u'bike (transport)': 2}),
#  (2894897,
#   {u'bike': 70,
#    u'bike (transport)': 14,
#    u'circuit training': 8,
#    u'cross-country skiing': 114,
#    u'fitness walking': 8,
#    u'hiking': 1,
#    u'kayaking': 11,
#    u'mountain bike': 204,
#    u'orienteering': 232,
#    u'roller skiing': 10,
#    u'run': 243,
#    u'skate': 4,
#    u'yoga': 4}),
#  (212295,
#   {u'bike': 29,
#    u'climbing': 3,
#    u'core stability training': 22,
#    u'cross-country skiing': 16,
#    u'hiking': 10,
#    u'indoor cycling': 2,
#    u'mountain bike': 8,
#    u'run': 813,
#    u'snowboarding': 1,
#    u'snowshoeing': 13,
#    u'swimming': 2}),
#  (508935, {u'bike': 672, u'mountain bike': 239, u'run': 6, u'walk': 1}),
#  (7516129,
#   {u'bike': 3,
#    u'bike (transport)': 1,
#    u'cross-country skiing': 1,
#    u'orienteering': 32,
#    u'run': 864,
#    u'walk': 14}),
#  (8446566,
#   {u'bike': 19,
#    u'bike (transport)': 4,
#    u'core stability training': 19,
#    u'mountain bike': 68,
#    u'orienteering': 7,
#    u'run': 173,
#    u'walk': 599,
#    u'weight training': 6}),
#  (14066832, {u'bike': 844, u'indoor cycling': 1, u'run': 49}),
#  (510054,
#   {u'bike': 468,
#    u'bike (transport)': 167,
#    u'indoor cycling': 4,
#    u'mountain bike': 22,
#    u'run': 227,
#    u'swimming': 1}),
#  (2145516,
#   {u'bike': 398,
#    u'bike (transport)': 9,
#    u'core stability training': 3,
#    u'run': 462,
#    u'walk': 6}),
#  (2486861,
#   {u'bike': 440, u'indoor cycling': 21, u'mountain bike': 409, u'run': 1}),
#  (751448, {u'run': 846}),
#  (14176671, {u'bike': 810, u'run': 35}),
#  (764981, {u'bike': 834}),
#  (4446822, {u'bike': 267, u'bike (transport)': 565, u'run': 1}),
#  (12200275, {u'bike': 712, u'indoor cycling': 113}),
#  (4774109, {u'bike': 812, u'run': 5}),
#  (56291,
#   {u'bike': 12,
#    u'bike (transport)': 11,
#    u'orienteering': 1,
#    u'run': 783,
#    u'treadmill running': 3,
#    u'walk': 1}),
#  (2600099,
#   {u'bike': 724,
#    u'bike (transport)': 3,
#    u'cross-country skiing': 3,
#    u'downhill skiing': 4,
#    u'hiking': 3,
#    u'kayaking': 3,
#    u'orienteering': 20,
#    u'run': 24,
#    u'skate': 1,
#    u'walk': 24}),
#  (3736342, {u'bike': 8, u'mountain bike': 3, u'run': 785}),
#  (2333172,
#   {u'bike': 392,
#    u'hiking': 11,
#    u'mountain bike': 53,
#    u'run': 337,
#    u'walk': 1}),
#  (1706844,
#   {u'bike': 709,
#    u'core stability training': 6,
#    u'fitness walking': 7,
#    u'indoor cycling': 42,
#    u'mountain bike': 10,
#    u'run': 7}),
#  (1998312,
#   {u'bike': 557,
#    u'bike (transport)': 1,
#    u'indoor cycling': 3,
#    u'mountain bike': 178,
#    u'run': 27,
#    u'skate': 14}),
#  (4496645, {u'bike': 654, u'bike (transport)': 121}),
#  (7996903, {u'run': 771}),
#  (2102320,
#   {u'bike': 751,
#    u'core stability training': 1,
#    u'mountain bike': 12,
#    u'run': 2}),
#  (5979382, {u'bike': 347, u'run': 414}),
#  (791908,
#   {u'bike': 343,
#    u'bike (transport)': 20,
#    u'core stability training': 3,
#    u'cross-country skiing': 1,
#    u'hiking': 3,
#    u'kayaking': 1,
#    u'mountain bike': 86,
#    u'orienteering': 4,
#    u'run': 285,
#    u'walk': 1}),
#  (9882712,
#   {u'bike': 413,
#    u'core stability training': 1,
#    u'cross-country skiing': 9,
#    u'golf': 1,
#    u'hiking': 23,
#    u'mountain bike': 19,
#    u'run': 255,
#    u'snowshoeing': 6,
#    u'walk': 6}),
#  (11884453,
#   {u'bike': 203,
#    u'bike (transport)': 43,
#    u'gymnastics': 2,
#    u'indoor cycling': 1,
#    u'mountain bike': 51,
#    u'run': 428,
#    u'walk': 2}),
#  (68009,
#   {u'bike': 16,
#    u'bike (transport)': 1,
#    u'core stability training': 1,
#    u'run': 697}),
#  (432096,
#   {u'bike': 114,
#    u'bike (transport)': 98,
#    u'cross-country skiing': 72,
#    u'fitness walking': 1,
#    u'hiking': 15,
#    u'run': 408,
#    u'walk': 6}),
#  (13149722,
#   {u'bike': 525,
#    u'bike (transport)': 40,
#    u'elliptical': 1,
#    u'mountain bike': 9,
#    u'orienteering': 3,
#    u'roller skiing': 4,
#    u'run': 128,
#    u'walk': 2}),
#  (6692748, {u'bike': 703}),
#  (3987593,
#   {u'bike': 135,
#    u'fitness walking': 8,
#    u'run': 237,
#    u'soccer': 1,
#    u'treadmill running': 1,
#    u'walk': 313}),
#  (6601602, {u'bike': 3, u'run': 691}),
#  (9335429, {u'bike': 1, u'run': 693}),
#  (10719156, {u'bike': 162, u'run': 240, u'walk': 285}),
#  (775277,
#   {u'bike': 9,
#    u'gymnastics': 2,
#    u'mountain bike': 1,
#    u'run': 541,
#    u'walk': 131}),
#  (2076057, {u'run': 681}),
#  (2849785,
#   {u'bike': 279,
#    u'core stability training': 2,
#    u'hiking': 1,
#    u'run': 398,
#    u'walk': 1}),
#  (9345869,
#   {u'cross-country skiing': 12,
#    u'hiking': 1,
#    u'orienteering': 124,
#    u'run': 538,
#    u'skate': 4,
#    u'walk': 1}),
#  (2282039,
#   {u'bike': 277,
#    u'core stability training': 4,
#    u'cross-country skiing': 1,
#    u'indoor cycling': 13,
#    u'rowing': 5,
#    u'run': 368}),
#  (14204020,
#   {u'bike': 251,
#    u'bike (transport)': 172,
#    u'core stability training': 1,
#    u'run': 231}),
#  (5727574,
#   {u'bike': 8,
#    u'bike (transport)': 3,
#    u'circuit training': 1,
#    u'cross-country skiing': 171,
#    u'fitness walking': 4,
#    u'hiking': 5,
#    u'mountain bike': 49,
#    u'roller skiing': 83,
#    u'run': 294,
#    u'skate': 22,
#    u'stair climing': 2,
#    u'walk': 7,
#    u'weight training': 1}),
#  (6961546, {u'bike': 1, u'bike (transport)': 7, u'run': 641}),
#  (331586,
#   {u'bike': 133,
#    u'core stability training': 12,
#    u'cross-country skiing': 44,
#    u'gymnastics': 1,
#    u'kayaking': 1,
#    u'orienteering': 6,
#    u'run': 435,
#    u'skate': 1,
#    u'snowboarding': 2,
#    u'snowshoeing': 1,
#    u'walk': 1,
#    u'weight training': 9}),
#  (2909018, {u'bike': 632, u'run': 11}),
#  (3021311,
#   {u'bike': 151,
#    u'bike (transport)': 14,
#    u'cross-country skiing': 11,
#    u'mountain bike': 5,
#    u'orienteering': 4,
#    u'run': 448,
#    u'walk': 9}),
#  (5278840,
#   {u'bike': 580, u'indoor cycling': 4, u'mountain bike': 40, u'run': 17}),
#  (890789,
#   {u'bike': 345,
#    u'bike (transport)': 130,
#    u'core stability training': 1,
#    u'mountain bike': 161,
#    u'run': 2,
#    u'walk': 1}),
#  (2479025,
#   {u'bike': 291,
#    u'core stability training': 73,
#    u'indoor cycling': 2,
#    u'mountain bike': 52,
#    u'run': 209,
#    u'treadmill running': 10}),
#  (240120,
#   {u'bike': 562, u'core stability training': 4, u'indoor cycling': 67}),
#  (13303518, {u'bike': 632, u'bike (transport)': 1}),
#  (4399772,
#   {u'bike': 364, u'indoor cycling': 33, u'mountain bike': 206, u'run': 29}),
#  (7178673,
#   {u'bike': 30,
#    u'bike (transport)': 3,
#    u'mountain bike': 199,
#    u'run': 390,
#    u'walk': 8}),
#  (171814,
#   {u'bike': 104,
#    u'circuit training': 1,
#    u'cross-country skiing': 49,
#    u'indoor cycling': 2,
#    u'mountain bike': 346,
#    u'roller skiing': 22,
#    u'run': 99,
#    u'weight training': 1}),
#  (3575734,
#   {u'bike': 109,
#    u'bike (transport)': 1,
#    u'core stability training': 3,
#    u'mountain bike': 9,
#    u'run': 497,
#    u'walk': 1}),
#  (3289673, {u'bike': 608, u'bike (transport)': 3, u'indoor cycling': 4}),
#  (8875079,
#   {u'bike (transport)': 1,
#    u'hiking': 2,
#    u'run': 603,
#    u'tennis': 4,
#    u'walk': 3}),
#  (8799177, {u'bike': 462, u'indoor cycling': 147}),
#  (11917849, {u'bike': 536, u'mountain bike': 51, u'run': 14}),
#  (2155974, {u'bike': 488, u'bike (transport)': 4, u'run': 107, u'walk': 1}),
#  (818925, {u'bike': 23, u'run': 576}),
#  (368603,
#   {u'bike': 1,
#    u'bike (transport)': 3,
#    u'fitness walking': 12,
#    u'mountain bike': 20,
#    u'orienteering': 1,
#    u'run': 550,
#    u'walk': 4,
#    u'weight training': 1}),
#  (7313790, {u'mountain bike': 201, u'run': 384}),
#  (5641621, {u'bike': 585}),
#  (4832531,
#   {u'bike': 432,
#    u'bike (transport)': 89,
#    u'indoor cycling': 32,
#    u'mountain bike': 20,
#    u'run': 6,
#    u'walk': 3}),
#  (3411439,
#   {u'bike': 124,
#    u'bike (transport)': 17,
#    u'core stability training': 9,
#    u'indoor cycling': 1,
#    u'mountain bike': 1,
#    u'run': 424,
#    u'walk': 4}),
#  (139383,
#   {u'bike': 364,
#    u'bike (transport)': 2,
#    u'indoor cycling': 134,
#    u'mountain bike': 57,
#    u'rowing': 1,
#    u'run': 19}),
#  (4403506, {u'bike': 569, u'bike (transport)': 6}),
#  (653747, {u'bike': 495, u'run': 77, u'walk': 2}),
#  (2974312,
#   {u'core stability training': 12,
#    u'cross-country skiing': 26,
#    u'fitness walking': 1,
#    u'gymnastics': 6,
#    u'roller skiing': 78,
#    u'run': 448,
#    u'skate': 2}),
#  (1842744,
#   {u'bike': 198,
#    u'bike (transport)': 73,
#    u'core stability training': 9,
#    u'indoor cycling': 7,
#    u'mountain bike': 3,
#    u'run': 262,
#    u'treadmill running': 18,
#    u'weight training': 3}),
#  (2358,
#   {u'bike': 19,
#    u'bike (transport)': 106,
#    u'circuit training': 26,
#    u'core stability training': 10,
#    u'run': 384,
#    u'swimming': 9,
#    u'walk': 1,
#    u'weight training': 17}),
#  (3089500,
#   {u'bike': 305,
#    u'bike (transport)': 184,
#    u'mountain bike': 70,
#    u'run': 12,
#    u'walk': 1}),
#  (745030,
#   {u'bike': 52,
#    u'bike (transport)': 1,
#    u'indoor cycling': 3,
#    u'run': 509,
#    u'swimming': 1,
#    u'weight training': 1}),
#  (3748741, {u'bike': 378, u'bike (transport)': 188}),
#  (851531,
#   {u'bike': 206,
#    u'core stability training': 3,
#    u'downhill skiing': 1,
#    u'fitness walking': 1,
#    u'indoor cycling': 1,
#    u'mountain bike': 14,
#    u'run': 337})]
# time: 13min 57s

# %%
# Lets figure out where user 4997910 lives / works.
# So many bike commutes probably will be able top guess based on heat map

_user = []

for _i in endoHR:
    if _i['userId'] == 3714939:
        _user.append(_i['series'])
# Out:
# time: 2.22 s

# %%
_user = [ item for sublist in _user for item in sublist]
# Out:
# time: 477 ms

# %%
print len(_user)
_user[:10]
# Out:
# 1037957
# [[1420806711, 50, 0.0, -40.3559419233, 175.6133818533],
#  [1420806712, 50, 0.0, -40.355941169, 175.6133815181],
#  [1420806714, 50, 0.0, -40.3559444379, 175.6133960187],
#  [1420806716, 51, 4.0, -40.3559674043, 175.6134251039],
#  [1420806717, 51, 6.4, -40.3559788875, 175.61344304120001],
#  [1420806721, 55, 8.8, -40.3560434282, 175.6135059893],
#  [1420806722, 59, 8.8, -40.3560859244, 175.6135239266],
#  [1420806724, 61, 8.8, -40.3561502974, 175.6135692727],
#  [1420806727, 67, 8.8, -40.356249623, 175.6136252638],
#  [1420806730, 68, 8.8, -40.3563284967, 175.61369148080001]]
# time: 11.1 ms

# %%
#_user_lat = [round(_i[3],3) for _i in _user]
#_user_long = [round(_i[4],3) for _i in _user]
_user_lat_long = [(round(_i[3],3),round(_i[4],3)) for _i in _user]
# Out:
# time: 2.58 s

# %%
_weighted_user_lat_long_dict = {}
for _i in _user:
    _tmp_lat_long = (round(_i[3],3),round(_i[4],3))
    
    if _tmp_lat_long not in _weighted_user_lat_long_dict:
        _weighted_user_lat_long_dict[_tmp_lat_long] = 1
    else:
        _weighted_user_lat_long_dict[_tmp_lat_long] += 1

_weighted_user_lat_long = []
for k, v in _weighted_user_lat_long_dict.iteritems():
    _weighted_user_lat_long.append((k[0],k[1],v))
# Out:
# time: 2.4 s

# %%
# gmap = gmplot.GoogleMapPlotter(0, 0, 2)
# # plot heatmap
# gmap.heatmap(_user_lat, _user_long)

# gmap.draw("/tmp/workout_heatmap_3714939.html")
# Out:
# time: 865 µs

# %%
m = gmaps.Map()
heatmap_layer = gmaps.WeightedHeatmap(data=_weighted_user_lat_long)
m.add_layer(heatmap_layer)

heatmap_layer.max_intensity = 90
heatmap_layer.point_radius = 3
m
# Out:
# time: 1.45 s

# %% [markdown]
# ### Was able to determine where this user likely lives, and where they likely work
#
# ### Lets try the top 5 users

# %%
# _top_users = [ _j[0] for _j  in sorted(_uid_freq_detail2, key=lambda x: sum(x[1].values()) , reverse=True)[:10]]

# for _j in log_progress(_top_users):
#     _user = []
#     for _i in endoHR:
#         if _i['userId'] == _j:
#             _user.append(_i['series'])

#     # Flatten
#     _user = [ item for sublist in _user for item in sublist]
#     _user_lat = [_i[3] for _i in _user]
#     _user_long = [_i[4] for _i in _user]

#     gmap = gmplot.GoogleMapPlotter(0, 0, 2)
#     # plot heatmap
#     gmap.heatmap(_user_lat, _user_long)
#     # map markers
#     #gmap.scatter(_user_lat, _user_long, '#3B0B39', size=40, marker=False)
#     #gmap.scatter(_user_lat, _user_long, 'k', marker=True)
#     # Not sure..
#     #gmap.plot(_user_lat, _user_long, 'cornflowerblue', edge_width=10)


#     gmap.draw("/tmp/workout_heatmap_%s.html"%_j)
# Out:
# time: 2.63 ms

# %% [markdown]
# ## Lets get summary stats of series time

# %%
endoHR_stats = []

for _endoHR in log_progress(endoHR, every=1):
    _summary = { 'average_diff': 0, 'median_diff': [], 'delta': 0, }
    
    _timestamps = [item[0] for item in _endoHR['series']]
    
    # only concern ourselves with those more than 60 timestamps in the activity.
    if len(_timestamps) < 60:
        continue
    
    _summary['delta'] = _timestamps[-1] - _timestamps[0]
    
    
    for _i, _timestamp in enumerate(_timestamps[:-2]):
        _diff = _timestamps[_i+1] - _timestamps[_i]
        _summary['average_diff'] += _diff
        _summary['median_diff'].append(_diff)
        
    try:
        _summary['average_diff'] = _summary['average_diff'] / len(_timestamps)
        _summary['median_diff'] = sorted(_summary['median_diff'])[len(_timestamps)/2]
    except:
        print len(_timestamps)
    endoHR_stats.append(_summary)
# Out:
# time: 11min 21s

# %%
endoHR_stats
print "Average"
print scipy.stats.describe([_i['average_diff'] for _i in endoHR_stats])

print ""
print "Median"
print scipy.stats.describe([_i['median_diff'] for _i in endoHR_stats])
# Out:
# Average
# DescribeResult(nobs=246420, minmax=(-524255, 1189043), mean=43.126889051213375, variance=26356953.600974083, skewness=161.5038490255816, kurtosis=31574.10763284236)
#
# Median
# DescribeResult(nobs=246420, minmax=(1, 8157), mean=9.070489408327246, variance=332.74946168508649, skewness=362.57780534783524, kurtosis=161564.4770818536)
# time: 705 ms

# %% [markdown]
# ## Heartrate analysis

# %%
_heart_rates = [ item[1] for sublist in endoHR for item in sublist['series']]
# Out:
# time: 2min 54s

# %%
plt.hist(sorted(_heart_rates),bins=100, log=True)
plt.show()
# Out:
# time: 45.1 s

# %%
# heart rate summary stats
print scipy.stats.describe(_heart_rates)
# Out:
# DescribeResult(nobs=111541956, minmax=(-2604, 18514), mean=138.60500511574318, variance=771.81354229537953, skewness=106.39291815493738, kurtosis=58196.45830942226)
# time: 16.2 s

# %% [markdown]
# #### Looks like there is a fair amount of garbage in the heart rate data. Min = -706, Max = 1001. Lets set some limits.
#
# from: https://www.reddit.com/r/askscience/comments/1opolp/what_is_the_fastest_the_average_human_heart_could/
#
# ```
# The absolute refractory period of cardiac muscle is between 250 and 300 ms. That means cardiac contractions are physiologically limited to 200-240 beats per minute.
# ```
#
# #### So lets set a max of 250 and min of 40. Below that likely to be error.

# %%
_bad_heart_rates = [ _i for _i in _heart_rates if _i not in range(40,250)]
_heart_rates = [ _i for _i in _heart_rates if _i in range(40,250)]
# Out:
# time: 10min

# %%
print scipy.stats.describe(_heart_rates)
# Out:
# DescribeResult(nobs=111142319, minmax=(40, 249), mean=139.08152750528805, variance=531.23616857223021, skewness=-0.29070481404703746, kurtosis=0.3935075549853555)
# time: 12.8 s

# %%
plt.hist(sorted(_heart_rates),bins=100, log=True)
plt.show()
# Out:
# time: 39.4 s

# %% [markdown]
# #### Bad heart rate numbers

# %%
plt.hist(sorted(_bad_heart_rates),bins=100, log=True)
plt.show()
# Out:
# time: 2.21 s

# %% [markdown]
# ## Speed analysis

# %%
_speed = [ item[5] for sublist in endoHR for item in sublist['series'] if sublist['speed_included'] == True]
# Out:
# time: 1min 6s

# %%
plt.hist(sorted(_speed),bins=100, log=True)
plt.show()
# Out:
# time: 30.5 s

# %%
print scipy.stats.describe(_speed)
# Out:
# DescribeResult(nobs=21360108, minmax=(0.0, 235.904), mean=19.953571130355542, variance=109.44997345313584, skewness=0.7420971547459682, kurtosis=0.9295458511734966)
# time: 2.73 s

# %% [markdown]
# #### No speed below zero, but seems unlikely someone got up to 235 MPH (assuming it is MPH, need to check. 235KM/h is just as unlikely). Lets look at it by sport

# %%
for _i in exercise_types.keys():
    _speed = [ item[5] for sublist in endoHR for item in sublist['series'] if sublist['speed_included'] == True and sublist['sport'] == _i]
    print "------"
    print _i
    print len(_speed)
    if len(_speed) == 0:
        continue
    plt.hist(sorted(_speed),bins=100, log=True)
    plt.title(_i)
    plt.show()
# Out:
# ------
# bike
# 10592166
# ------
# golf
# 0
# ------
# weight training
# 1492
# ------
# hiking
# 4431
# ------
# snowshoeing
# 0
# ------
# walk
# 117162
# ------
# skate
# 8774
# ------
# gymnastics
# 0
# ------
# skateboarding
# 0
# ------
# mountain bike
# 632433
# ------
# bike (transport)
# 619705
# ------
# basketball
# 0
# ------
# yoga
# 352
# ------
# dancing
# 0
# ------
# tennis
# 0
# ------
# orienteering
# 11198
# ------
# aerobics
# 759
# ------
# elliptical
# 4397
# ------
# fitness walking
# 22673
# ------
# soccer
# 219
# ------
# martial arts
# 1452
# ------
# windsurfing
# 0
# ------
# wheelchair
# 0
# ------
# stair climing
# 20
# ------
# run
# 8792471
# ------
# downhill skiing
# 533
# ------
# circuit training
# 877
# ------
# table tennis
# 0
# ------
# squash
# 0
# ------
# pilates
# 499
# ------
# indoor cycling
# 472706
# ------
# climbing
# 0
# ------
# beach volleyball
# 0
# ------
# core stability training
# 24820
# ------
# rugby
# 0
# ------
# sailing
# 0
# ------
# rowing
# 6274
# ------
# kayaking
# 11459
# ------
# kite surfing
# 0
# ------
# step counter
# 0
# ------
# cross-country skiing
# 15528
# ------
# badminton
# 996
# ------
# roller skiing
# 14473
# ------
# horseback riding
# 500
# ------
# snowboarding
# 0
# ------
# scuba diving
# 0
# ------
# treadmill walking
# 0
# ------
# treadmill running
# 1739
# ------
# swimming
# 0
# time: 26min 52s

# %% [markdown]
# ### Altitude

# %%
_altitude = [ item[2] for sublist in endoHR for item in sublist['series'] ]
# Out:
# time: 1min 30s

# %%
plt.hist(sorted(_altitude),bins=100, log=True)
plt.show()
# Out:
# time: 12min 45s

# %%
print scipy.stats.describe(_altitude)
# Out:
# DescribeResult(nobs=111541956, minmax=(-9999.0, 1.0000000000000001e+25), mean=6.9928843636200899e+18, variance=6.9928795362685788e+43, skewness=1195.8353051006004, kurtosis=1430020.07692425)
# time: 1min 34s

# %%
_high_altitude_locations = [item[3:5] for sublist in endoHR for item in sublist['series'] if item[2] > 3500]
# Out:
# time: 1min 33s

# %%
_high_altitude_locations[:5]
# Out:
# [[51.9039747398, 4.1610558517],
#  [50.3360609, 19.598095700000002],
#  [50.3365829, 19.5982297],
#  [50.3366396, 19.5982963],
#  [50.3366856, 19.5984963]]
# time: 44 ms

# %%
# # declare the center of the map, and how much we want the map zoomed in
# gmap = gmplot.GoogleMapPlotter(0, 0, 2)
# # plot heatmap
# gmap.scatter([_i[0] for _i in _high_altitude_locations ],[_i[1] for _i in _high_altitude_locations ])

# gmap.draw("/tmp/high_altitude_workout_locations.html")

_lat_longs = zip([_i[0] for _i in _high_altitude_locations ],[_i[1] for _i in _high_altitude_locations ])

m = gmaps.Map()
heatmap_layer = gmaps.Heatmap(data=_lat_longs)
m.add_layer(heatmap_layer)

heatmap_layer.max_intensity = 90
heatmap_layer.point_radius = 3
m
# Out:
# time: 18.3 s

# %%
for _i in endoHR:
    if len([1 for item in _i['series'] if item[2] > 5000]) > 0:
        print _i['gender'], _i['id'], _i['sport'], _i['url'], _i['userId']
# Out:
# male 227890083 bike https://www.endomondo.com/users/8467445/workouts/227890083 8467445
# male 378773782 run https://www.endomondo.com/users/1655221/workouts/378773782 1655221
# male 374792411 run https://www.endomondo.com/users/1655221/workouts/374792411 1655221
# male 374792746 bike https://www.endomondo.com/users/1655221/workouts/374792746 1655221
# male 331427820 run https://www.endomondo.com/users/12726303/workouts/331427820 12726303
# male 330216529 bike https://www.endomondo.com/users/3559941/workouts/330216529 3559941
# male 329706837 run https://www.endomondo.com/users/3559941/workouts/329706837 3559941
# male 446832415 run https://www.endomondo.com/users/260784/workouts/446832415 260784
# male 425757459 run https://www.endomondo.com/users/260784/workouts/425757459 260784
# male 425757501 run https://www.endomondo.com/users/260784/workouts/425757501 260784
# male 422579694 run https://www.endomondo.com/users/260784/workouts/422579694 260784
# male 419740108 run https://www.endomondo.com/users/260784/workouts/419740108 260784
# male 419740120 run https://www.endomondo.com/users/260784/workouts/419740120 260784
# male 303089213 run https://www.endomondo.com/users/3275003/workouts/303089213 3275003
# male 303089209 bike https://www.endomondo.com/users/3275003/workouts/303089209 3275003
# male 303089161 run https://www.endomondo.com/users/3275003/workouts/303089161 3275003
# male 299466166 run https://www.endomondo.com/users/3275003/workouts/299466166 3275003
# male 298760634 run https://www.endomondo.com/users/3275003/workouts/298760634 3275003
# male 295030827 run https://www.endomondo.com/users/3275003/workouts/295030827 3275003
# male 294778592 run https://www.endomondo.com/users/3275003/workouts/294778592 3275003
# male 292601805 run https://www.endomondo.com/users/3275003/workouts/292601805 3275003
# male 280239002 run https://www.endomondo.com/users/3275003/workouts/280239002 3275003
# male 279679502 run https://www.endomondo.com/users/3275003/workouts/279679502 3275003
# male 278752846 run https://www.endomondo.com/users/3275003/workouts/278752846 3275003
# male 74405818 core stability training https://www.endomondo.com/users/212295/workouts/74405818 212295
# male 74405834 core stability training https://www.endomondo.com/users/212295/workouts/74405834 212295
# male 74405844 core stability training https://www.endomondo.com/users/212295/workouts/74405844 212295
# male 74405869 core stability training https://www.endomondo.com/users/212295/workouts/74405869 212295
# male 74405875 core stability training https://www.endomondo.com/users/212295/workouts/74405875 212295
# time: 2min 42s

# %% [markdown]
# ## Sanity check latitude and longitude
#
# #### Values should only between -90 / 90 & -180 / 180

# %%
_latitude = [ item[3] for sublist in endoHR for item in sublist['series'] ]
_longitude = [ item[4] for sublist in endoHR for item in sublist['series'] ]

print scipy.stats.describe(_latitude)
print scipy.stats.describe(_longitude)
# Out:
# DescribeResult(nobs=111541956, minmax=(-51.727738268700001, 84.656357271600001), mean=42.990537246878269, variance=436.1250714816702, skewness=-2.3198240135289803, kurtosis=5.337451112380673)
# DescribeResult(nobs=111541956, minmax=(-160.00089948070001, 177.36661255359999), mean=12.67773121705511, variance=2548.8915373249829, skewness=0.25068693144068366, kurtosis=1.7718869145158092)
# time: 10min 2s

# %% [markdown]
# #### Looks good

# %% [markdown]
# ## Check San Diego users

# %%
sd_events = []
for _endoHR in log_progress(endoHR):
    _mid_point = []
    
    if len(_endoHR['series']) < 10:
        continue
        
    _series = _endoHR['series']
    _point = _series[len(_series) / 2]
    
    _lat = _point[3]
    _long = _point[4]
    
    if _lat >= 32.4 and _lat <= 33.0 and _long <= -116.9 and _long >= -117.5:
        sd_events.append(_endoHR)
# Out:
# time: 21.4 s

# %%
print "Found %s records near SD"%len(sd_events)
# Out:
# Found 26 records near SD
# time: 7.78 ms

# %%
print set([ _i['userId'] for _i in sd_events ])
# Out:
# set([3276737, 504709, 8888545, 7430612, 458903, 4226525])
# time: 31.7 ms

# %%
_lat_longs = []
for _endoHR in sd_events:
    _series = _endoHR['series']
    
    [ _lat_longs.append([_i[3], _i[4]]) for _i in _series]
# Out:
# time: 4min 35s

# %%
len(_lat_longs)
# Out:
# 9524
# time: 46.6 ms

# %%
m = gmaps.Map()
heatmap_layer = gmaps.Heatmap(data=_lat_longs)
m.add_layer(heatmap_layer)

heatmap_layer.max_intensity = 100
heatmap_layer.point_radius = 5
m
# Out:
# time: 2.85 s
